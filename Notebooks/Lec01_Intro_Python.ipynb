# %% [markdown]
# # **Basic Programming (Python)**

# %% [markdown]
# #**1. 마크다운을 활용하여 다음과 같은 출력을 해보자.**

# %% [markdown]
# ![Screen Shot 2022-02-28 at 18.44.47.png](data:image/png;base64,...)

# %% [markdown]
# # **2. 'Hello World'**

# %%
print('Hello World')

# %% [markdown]
# ## 2-1. 'Hello Python' 을 출력해보자.

# %% [markdown]
# ## 2-2. 다양한 문자열과 숫자 출력

# %%
print('Hello', 'World!')

# %%
print('Hello'+'World!')

# %%
print(100)

# %%
print(2+4)

# %%
print('2+4')

# %% [markdown]
# ## 2-3. 간단한 숫자 출력하기와 연산

# %%
10 + 300

# %%
10 - 300

# %%
10 * 300

# %%
10 / 300

# %%
345%100

# %%
10 + 20 * 30
