# %% [markdown]
# # **Lec1-1. Problem set (으뜸 파이썬 1장)**

# %% [markdown]
# ## 1. 다음 파이썬 프로그램의 출력결과는 무엇인가?
# ---
# ```
# (1) print(100)
# (2) print(100 + 200)
# (3) print('100 + 200')
# (4) print(100, 200)
# (5) print('100', '200')
# (6) print('Hello Python!')
# (7) print('Hello','Python', '!')
# (8) print('Hello'+'Python'+'!')
# (9) print('**********')
# (10) print('*' * 10)
# ```

# %% [markdown]
# ## 2. 다음 프로그램의 어떤 오류를 출력하는가? 실행시 나타나는 오류를 적고 이 오류를 수정한 후 실행시켜보시오.
# ---
#
# ```
# (1) Print('Hello Python!')
# (2) print("Hello Python!')
# (3) print(Hello Python!)
# (4) print(100 + '200')
# (5) print('3의 3제곱 :', 3 ^ 3)
# ```

# %% [markdown]
# ## 3. 100과 200의 두 값이 있을 경우, 이 값들의 평균값을 다음과 같이 출력하는 프로그램을 작성하시오.
# ---
# 실행 결과
#
#
# ```
# 100과 200의 평균값 : 150.0
# ```
